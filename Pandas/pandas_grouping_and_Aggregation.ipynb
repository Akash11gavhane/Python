# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\AKASH\\Downloads\\data_dev_script.csv")

# %%
schema_df = pd.read_csv("C:\\Users\\AKASH\\Downloads\\survey_results_schema.csv")

# %%
people = {
    "first": ["Corey", 'Jane', 'John' , "Adam"], 
    "last": ["Schafer", 'Doe', 'Doe' , "Doe"], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com' , "a@email.com"]
}

# %%
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                            WelcomeChange  \
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_11628\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].count()
# Out:
# 88883

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df["SocialMedia"].value_counts().head()
# Out:
# Reddit      14374
# YouTube     13830
# WhatsApp    13347
# Facebook    13178
# Twitter     11398
# Name: SocialMedia, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
country_grp.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'

# %%
df.loc[filt]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
df[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(15)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#              LinkedIn                     1
#              Twitter                      1
# Albania      WhatsApp                    18
#              Facebook                    16
#              Instagram                   13
#              YouTube                     10
#              Twitter                      8
#              LinkedIn                     7
#              Reddit                       6
#              I don't use social media     4
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
country_grp['ConvertedComp'].agg(['median' , 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median' , 'mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
country_grp['ConvertedComp'].agg(['median' , 'mean']).loc[['India' , 'United States']]
# Out:
#                  median           mean
# Country
# India           10080.0   28057.664916
# United States  110000.0  249546.254589

# %%
filt= df['Country'] == "India"

df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 3105

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains("Python"))
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_11628\3740587970.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains("Python"))
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 88875    False
# 88876     True
# 88877    False
# 88878    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88751, dtype: object

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains("Python").value_counts())
# Out:
# Country
# Afghanistan  False    31
#              True      8
# Albania      False    60
#              True     23
# Algeria      False    86
#                       ..
# Yemen        True      3
# Zambia       False     8
#              True      4
# Zimbabwe     False    25
#              True     14
# Name: LanguageWorkedWith, Length: 335, dtype: int64

# %%
country_respondants = df['Country'].value_counts()
country_respondants
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondants , country_uses_python] , axis = 'columns' ,  sort = False)

# %%
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns = {'Country' : 'NumberRespondants' , 'LanguageWorkedWith' : 'NumKnowsPython'} , inplace = True)

# %%
python_df
# Out:
#                    NumberRespondants  NumKnowsPython
# United States                  20949           10083
# India                           9061            3105
# Germany                         5866            2451
# United Kingdom                  5737            2384
# Canada                          3395            1558
# ...                              ...             ...
# Tonga                              1               0
# Timor-Leste                        1               1
# North Korea                        1               0
# Brunei Darussalam                  1               0
# Chad                               1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumberRespondants'])

# %%
python_df
# Out:
#                    NumberRespondants  NumKnowsPython  PctKnowsPython
# United States                  20949           10083        0.481312
# India                           9061            3105        0.342677
# Germany                         5866            2451        0.417832
# United Kingdom                  5737            2384        0.415548
# Canada                          3395            1558        0.458910
# ...                              ...             ...             ...
# Tonga                              1               0        0.000000
# Timor-Leste                        1               1        1.000000
# North Korea                        1               0        0.000000
# Brunei Darussalam                  1               0        0.000000
# Chad                               1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumberRespondants']) * 100

# %%
python_df
# Out:
#                    NumberRespondants  NumKnowsPython  PctKnowsPython
# United States                  20949           10083       48.131176
# India                           9061            3105       34.267741
# Germany                         5866            2451       41.783157
# United Kingdom                  5737            2384       41.554820
# Canada                          3395            1558       45.891016
# ...                              ...             ...             ...
# Tonga                              1               0        0.000000
# Timor-Leste                        1               1      100.000000
# North Korea                        1               0        0.000000
# Brunei Darussalam                  1               0        0.000000
# Chad                               1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by = 'PctKnowsPython' , ascending=False , inplace=True)

# %%
python_df
# Out:
#                                   NumberRespondants  NumKnowsPython  \
# Sao Tome and Principe                             1               1
# Timor-Leste                                       1               1
# Dominica                                          1               1
# Niger                                             1               1
# Turkmenistan                                      7               6
# ...                                             ...             ...
# Cape Verde                                        3               0
# Lao People's Democratic Republic                  3               0
# Malawi                                            2               0
# Liberia                                           2               0
# Chad                                              1               0
#
#                                   PctKnowsPython
# Sao Tome and Principe                 100.000000
# Timor-Leste                           100.000000
# ...

# %%
python_df.loc['Japan']
# Out:
# NumberRespondants    391.000000
# NumKnowsPython       182.000000
# PctKnowsPython        46.547315
# Name: Japan, dtype: float64

# %%
python_df.loc['India']
# Out:
# NumberRespondants    9061.000000
# NumKnowsPython       3105.000000
# PctKnowsPython         34.267741
# Name: India, dtype: float64
