# %% [markdown]
# ### **`Pandas DataFrame`**
#
#         dataframes are the collection of multiple series objects
#
#         a table is dataframe
#
#         pandas called table as dataframe --> it is 2D structure data
#
#
#         every single column and every single row in the dataframe is called as series

# %%
import numpy as np

import pandas as pd

# %% [markdown]
# ### **`Creating DataFrames`**

# %%
# using lists
# create dataframe using list

# if you want to make a dataframe then we need a 2D list --> list inside list

student_data = [
    [100 , 80 , 10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data , columns = ['iq' , 'marks' , 'package'])

# here using colummn parameter we specify the names for our column
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dictionary

# create a dataframe using dictionary

student_dict = {
    'iq' : [100 , 90 , 120 , 80],
    'marks' : [80 , 70 , 100 , 50],
    'package' : [10 , 7 , 14 , 2]
}

student = pd.DataFrame(student_dict)

student

# here there is no need to specify the column names like we specify in list
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
student_dict = {
    'name':['nitish','ankit','rupesh' , 'Akash'],
    'iq' : [100 , 90 , 120 , 80],
    'marks' : [80 , 70 , 100 , 50],
    'package' : [10 , 7 , 14 , 8]
}

student = pd.DataFrame(student_dict)

student
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1   ankit   90     70        7
# 2  rupesh  120    100       14
# 3   Akash   80     50        8

# %%
# using read_csv

movies = pd.read_csv("movies.csv")

movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl_matches = pd.read_csv('ipl-matches.csv')

ipl_matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ### **`DataFrames Attributes and methods`**

# %%
movies.shape

# shape attribute shows there are how many rows and columns are available in the dataset
# Out:
# (1629, 18)

# %%
ipl_matches.shape
# Out:
# (950, 20)

# %%
# dtypess

# it helps us to show the data type of columns or series present in the  dataframe

movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl_matches.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index

# using index attribute we can fetch any index from the dataframe
# like series it have auto generated indexes

movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl_matches.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
ipl_matches.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns 

# it fetch all the columns present in the data frame

movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# values

# this function all the values present in the data set

student.values
# Out:
# array([['nitish', 100, 80, 10],
#        ['ankit', 90, 70, 7],
#        ['rupesh', 120, 100, 14],
#        ['Akash', 80, 50, 8]], dtype=object)

# %%
ipl_matches.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail

movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies.tail(2)
# Out:
#        title_x     imdb_id                                        poster_path  \
# 1627     Daaka  tt10833860  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  Humsafar   tt2403201  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                    wiki_link   title_y original_title  \
# 1627     https://en.wikipedia.org/wiki/Daaka     Daaka          Daaka
# 1628  https://en.wikipedia.org/wiki/Humsafar  Humsafar       Humsafar
#
#       is_adult  year_of_release runtime         genres  imdb_rating  \
# 1627         0             2019     136         Action          7.4
# 1628         0             2011      35  Drama|Romance          9.0
#
#       imdb_votes                                              story  \
# 1627          38  Shinda tries robbing a bank so he can be wealt...
# 1628        2968  Sara and Ashar are childhood friends who share...
#
#                                                 summary tagline  \
# ...

# %%
# sample 

# show randomely one row from dataframe


movies.sample()
# Out:
#             title_x    imdb_id  \
# 753  Teen Thay Bhai  tt1867070
#
#                                            poster_path  \
# 753  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link         title_y  \
# 753  https://en.wikipedia.org/wiki/Teen_Thay_Bhai  Teen Thay Bhai
#
#      original_title  is_adult  year_of_release runtime        genres  \
# 753  Teen Thay Bhai         0             2011      \N  Comedy|Drama
#
#      imdb_rating  imdb_votes  \
# 753          4.3         297
#
#                                                  story  \
# 753  Bhatinda-based middle-classed Harpreet Gill is...
#
#                                                summary tagline  \
# 753  In order to inherit a mansion  three squabblin...     NaN
#
#                                      actors wins_nominations release_date
# 753  Om Puri|Deepak Dobriyal|Ragini Khanna|              NaN          NaN

# %%
ipl_matches.sample()
# Out:
#           ID       City        Date Season MatchNumber  \
# 112  1254079  Ahmedabad  2021-04-27   2021          22
#
#                            Team1           Team2  \
# 112  Royal Challengers Bangalore  Delhi Capitals
#
#                                 Venue      TossWinner TossDecision SuperOver  \
# 112  Narendra Modi Stadium, Ahmedabad  Delhi Capitals        field         N
#
#                      WinningTeam WonBy  Margin method Player_of_Match  \
# 112  Royal Challengers Bangalore  Runs     1.0    NaN  AB de Villiers
#
#                                           Team1Players  \
# 112  ['V Kohli', 'D Padikkal', 'RM Patidar', 'GJ Ma...
#
#                                           Team2Players Umpire1    Umpire2
# 112  ['PP Shaw', 'S Dhawan', 'SPD Smith', 'RR Pant'...  S Ravi  VK Sharma

# %%
ipl_matches.sample(5)

# to generate random 5 matches
# Out:
#           ID           City        Date   Season MatchNumber  \
# 599   598025     Chandigarh  2013-04-21     2013          29
# 443   829803     Chandigarh  2015-05-13     2015          50
# 390   980985  Visakhapatnam  2016-05-13     2016          43
# 861   392213      Centurion  2009-05-07     2009          33
# 177  1216538            NaN  2020-10-04  2020/21          17
#
#                            Team1                        Team2  \
# 599              Kings XI Punjab                Pune Warriors
# 443              Kings XI Punjab  Royal Challengers Bangalore
# 390               Mumbai Indians              Kings XI Punjab
# 861  Royal Challengers Bangalore             Rajasthan Royals
# 177               Mumbai Indians          Sunrisers Hyderabad
#
#                                                  Venue  \
# 599         Punjab Cricket Association Stadium, Mohali
# 443         Punjab Cricket Association Stadium, Mohali
# ...

# %%
# info 

# show multiple information about your dataframe at once

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe

# it gives mathematical summary only on the numerical columns

movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl_matches.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull()


movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl_matches.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicated

movies.duplicated().sum()
# Out:
# 0

# %%
ipl_matches.duplicated().sum()
# Out:
# 0

# %%
# rename

# to rename the column name of dataframe

student
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1   ankit   90     70        7
# 2  rupesh  120    100       14
# 3   Akash   80     50        8

# %%
student.rename(columns={"marks": "percentage","package":"lpa"})

# using these function we can change column name in our data frame
# Out:
#      name   iq  percentage  lpa
# 0  nitish  100          80   10
# 1   ankit   90          70    7
# 2  rupesh  120         100   14
# 3   Akash   80          50    8

# %% [markdown]
# ### **`Math Methods`**

# %%
# sum --> axis argument

movies.sum()
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_4160\1389060122.py:3: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.sum()
# title_x            Uri: The Surgical StrikeBattalion 609The Accid...
# imdb_id            tt8291224tt9472208tt6986710tt8108208tt6028796t...
# wiki_link          https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y            Uri: The Surgical StrikeBattalion 609The Accid...
# original_title     Uri: The Surgical StrikeBattalion 609The Accid...
# is_adult                                                           0
# year_of_release                                              3274720
# runtime            1381311121211029710910414812013415314313014311...
# genres             Action|Drama|WarWarBiography|DramaCrime|DramaD...
# ...

# %%
ipl_matches.sum()
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_4160\2152927772.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipl_matches.sum()
# ID                                                      788960985
# Date            2022-05-292022-05-272022-05-252022-05-242022-0...
# Season          2022202220222022202220222022202220222022202220...
# MatchNumber     FinalQualifier 2EliminatorQualifier 1706968676...
# Team1           Rajasthan RoyalsRoyal Challengers BangaloreRoy...
# Team2           Gujarat TitansRajasthan RoyalsLucknow Super Gi...
# Venue           Narendra Modi Stadium, AhmedabadNarendra Modi ...
# TossWinner      Rajasthan RoyalsRajasthan RoyalsLucknow Super ...
# TossDecision    batfieldfieldfieldbatfieldbatbatbatfieldfieldb...
# ...

# %%
student.sum(axis = 0)

# rowwise sum
# Out:
# name       nitishankitrupeshAkash
# iq                            390
# marks                         300
# package                        39
# dtype: object

# %%
student.sum(axis = 1)

# column wise
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_4160\3086027855.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   student.sum(axis = 1)
# 0    190
# 1    167
# 2    234
# 3    138
# dtype: int64

# %%
student.mean()
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_4160\262002444.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student.mean()
# iq         97.50
# marks      75.00
# package     9.75
# dtype: float64

# %% [markdown]
# ### **` Selecting Columns From Dataset`**

# %%
# single column

# how to fetch one single column from dataframe

movies['title_x']

# dataframeName['columnName']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
type(movies['title_x'])

# the output is in series
# Out:
# pandas.core.series.Series

# %%
ipl_matches['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple cols

# how to fetch multiple columns 

movies[['title_x' , 'year_of_release' , 'actors']]

# here we are passing a list of column name

# single column is in series

# multiple column output is dataframe
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
type(movies[['title_x' , 'year_of_release' , 'actors']])
# Out:
# pandas.core.frame.DataFrame

# %%
ipl_matches[['Team1' , 'Team2' , 'WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
student
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1   ankit   90     70        7
# 2  rupesh  120    100       14
# 3   Akash   80     50        8

# %%
student.set_index('name' , inplace=True)

# using these set_index function we can make any column to the index of that dataframe

# %%
student
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# ankit    90     70        7
# rupesh  120    100       14
# Akash    80     50        8

# %% [markdown]
# ### **`How to fetch Rows from Columns`**
#
# -   **`iloc`** - searches using index positions
# -   **`loc`** - searches using index labels

# %%
# single row

# how to fetch single row from dataframe

movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.iloc[4]
# Out:
# title_x                                               Evening Shadows
# imdb_id                                                     tt6028796
# poster_path                                                       NaN
# wiki_link               https://en.wikipedia.org/wiki/Evening_Shadows
# title_y                                               Evening Shadows
# original_title                                        Evening Shadows
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                           102
# genres                                                          Drama
# imdb_rating                                                       7.3
# imdb_votes                                                        280
# story               While gay rights and marriage equality has bee...
# ...

# %%
# multiple rows using iloc 

movies.iloc[0 : 5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
## access movies alternately 

movies.iloc[0 : 15 : 2]
# Out:
#                                  title_x    imdb_id  \
# 0               Uri: The Surgical Strike  tt8291224
# 2   The Accidental Prime Minister (film)  tt6986710
# 4                        Evening Shadows  tt6028796
# 6                          Fraud Saiyaan  tt5013008
# 8       Manikarnika: The Queen of Jhansi  tt6903440
# 10                                Amavas  tt8396186
# 12                             Hum Chaar  tt9319812
# 14                            Sonchiriya  tt8108200
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                 NaN
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
#
# ...

# %%
# fancy indexing

movies.iloc[[0 , 3 , 4]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 3           Why Cheat India  tt8108208
# 4           Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 3           Why Cheat India           Why Cheat India         0
# 4           Evening Shadows           Evening Shadows         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# using loc
# it fetches using labels 

student
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# ankit    90     70        7
# rupesh  120    100       14
# Akash    80     50        8

# %%
# single 


student.loc['Akash']
# Out:
# iq         80
# marks      50
# package     8
# Name: Akash, dtype: int64

# %%
# multiple rows using loc

student.loc['nitish' : 'rupesh']
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# ankit    90     70        7
# rupesh  120    100       14

# %%
# alternate fetching using loc

student.loc['nitish' : 'rupesh' : 2]
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# rupesh  120    100       14

# %%
# fancy indexing also

student.loc[["nitish" ,  "rupesh" , "Akash"]]
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# rupesh  120    100       14
# Akash    80     50        8

# %%
student
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# ankit    90     70        7
# rupesh  120    100       14
# Akash    80     50        8

# %%
student.iloc[0 : 4 ]
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# ankit    90     70        7
# rupesh  120    100       14
# Akash    80     50        8

# %%
student.iloc[0 : 4 : 2]
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# rupesh  120    100       14

# %%
student.iloc[[0 , 2 , 3]]
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# rupesh  120    100       14
# Akash    80     50        8

# %% [markdown]
# ### **`Selecting both rows and cols`**

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# fetch first 3 rows and first 3 columns

movies.iloc[0 : 3 , 0 : 3]


# datframeName.iloc[rows , columns]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0 : 2 , 'title_x' : 'poster_path' ]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
## while working with iloc we providing actual index number

# while working with loc we providng the names of the columns

# %% [markdown]
# ### **`Filtering DataFrame`**

# %%
ipl_matches.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the final winners from ipl dataset


mask = ipl_matches[ipl_matches['MatchNumber'] == 'Final']

new_df = mask

new_df[['Season' , 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# 

ipl_matches[ipl_matches['MatchNumber'] == 'Final'][['Season' , 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many superovers finishes have occured

ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_matches[ipl_matches['SuperOver'] == 'Y'].shape[0]

# there are 14 matches are played with superover
# Out:
# 14

# %%
# how many matches has csk won in kolkata

ipl_matches[(ipl_matches['City'] == 'Kolkata') & (ipl_matches['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage

(ipl_matches[ipl_matches[ 'TossWinner'] == ipl_matches['WinningTeam']].shape[0] / ipl_matches.shape[0] ) * 100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes > 10000

movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000) ].shape[0]
# Out:
# 43

# %%
 # Action movies with rating higher than 7.5
# mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)



mask1 = movies['genres'].str.split('|').apply(lambda x : 'Action' in x)

#mask1 = movies['genres'].str.contains('Action')
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
# write a function that can return the track record of 2 teams against each other

# %% [markdown]
# ### **`Adding new cols`**

# %%
# how to add completely new column

movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies['Country'] = 'India'

# %%
movies

# you can see in the last there was a column was added
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies['actors'].str.split('|').apply(lambda x : x[0] in x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 movies['actors'].str.split('|').apply(lambda x : x[0] in x)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# ...

# %%
# above error is because of missing value so we remove the missing value 
movies.dropna(inplace=True)

# %%
movies['Lead Actor'] = movies['actors'].str.split('|').apply(lambda x : x[0])

# %%
movies

# there was a last column called lead actor is made
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### **`Important DataFrame Functions`**

# %%
# astype

# astype() changes the datatype of the given function

ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl_matches['ID'] = ipl_matches['ID'].astype('int32')

# change from INT64 to INT32

# %%
ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# 

ipl_matches['Season'] = ipl_matches['Season'].astype('category')
ipl_matches['Team1'] = ipl_matches['Team1'].astype('category')
ipl_matches['Team2'] = ipl_matches['Team2'].astype('category')

# %%
ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl_matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# value_counts
