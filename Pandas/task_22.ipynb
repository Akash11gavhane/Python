# %%
import pandas as pd
import numpy as np
import re

pd.options.display.max_columns = None

# %% [markdown]
# ### `Question-1:`
#
# The dataset is based on NFTs. This is quite large. So, when you will read the dataset, you have to wait. The link of the dataset: https://tinyurl.com/2pfhncqw
#
# Your task is to make a pivote table by using the columns "verification_status", "contract_type", "rarity_score" and "last_sale_price" to find out the total values.

# %%
# code here

nft = pd.read_csv("nfts_train - nfts_train.csv")

nft.head()
# Out:
#    Unnamed: 0  rarity_score last_sale_date  last_sale_price  total_supply  \
# 0           0      2.000000        2022-11         1.266732             1
# 1           1     97.077216        2021-08         1.200357          8888
# 2           2    139.453086        2022-08         3.180572          8888
# 3           3    127.753445        2021-08         3.502910          8888
# 4           4    112.315719        2022-09         4.009567          8888
#
#   creation_date verification_status  n_of_traits contract_type  seller_fees  \
# 0       2022-04            verified            2           own       1000.0
# 1       2021-07            verified            5           own        500.0
# 2       2021-07            verified            5           own        500.0
# 3       2021-07            verified            5           own        500.0
# 4       2021-07            verified            5           own        500.0
#
#    platform_fees  openrarity_enabled  has_website  has_own_twitter  \
# 0            250               False        False             True
# 1            250               False        False             True
# 2            250               False        False             True
# 3            250               False        False             True
# 4            250               False        False             True
#
#    has_discord  has_medium  n_tweets_in_range   avg_likes  avg_replies  \
# 0         True       False                 31  187.967742     8.290323
# 1         True       False                 11  133.181818    13.454545
# 2         True       False                 11  133.181818    13.454545
# 3         True       False                 11  133.181818    13.454545
# 4         True       False                 11  133.181818    13.454545
#
#    avg_retweets  min_likes  min_replies  min_retweets  max_likes  max_replies  \
# 0     60.935484          0            0             2        591           28
# 1     55.181818          0            0             7        402           47
# 2     55.181818          0            0             7        402           47
# 3     55.181818          0            0             7        402           47
# 4     55.181818          0            0             7        402           47
#
#    max_retweets
# 0           380
# 1           239
# 2           239
# 3           239
# 4           239

# %%
nft.shape

nft = nft.head(15000)

# %%
nft.pivot_table(columns=['verification_status' , 'contract_type' , 'rarity_score']  , values='last_sale_price' , aggfunc='sum')
# Out:
# verification_status     verified                                         \
# contract_type                own
# rarity_score        2.000000     73.749066    74.687671    76.119817
# last_sale_price         1.266732     3.702687     0.328254     1.760772
#
# verification_status                                                      \
# contract_type
# rarity_score        77.203575    77.303307    79.451134    79.508146
# last_sale_price         2.106678     2.899499     1.958874     2.256287
#
# verification_status                                                      \
# contract_type
# rarity_score        79.558342    79.739948    79.756274    80.272985
# last_sale_price         3.346405     3.432223     1.792277     2.691276
#
# verification_status                                                      \
# contract_type
# rarity_score        80.413246    80.555894    80.653765    80.890161
# last_sale_price         2.343814      1.80296     1.001993     1.509433
#
# verification_status                                                      \
# contract_type
# rarity_score        80.991327    81.198774    81.408776    81.563529
# last_sale_price         2.303927     2.366214     2.957219     1.697425
#
# verification_status                                                      \
# contract_type
# rarity_score        81.623927    81.649756    81.671715    81.918003
# last_sale_price         1.100342      1.47943     0.506892     2.201965
#
# verification_status                                                      \
# contract_type
# rarity_score        81.965396    81.968227    82.125779    82.223508
# last_sale_price         1.102547     2.001559     0.334413     2.390356
#
# verification_status                                                      \
# contract_type
# rarity_score        82.237112    82.285655    82.353433    82.724432
# last_sale_price         3.007647     1.451954     2.503099     3.107195
#
# verification_status                                                      \
# contract_type
# rarity_score        82.772993    82.787485    82.886341    82.940784
# last_sale_price         1.878735     2.102711     0.906682     1.850069
#
# verification_status                                                      \
# contract_type
# rarity_score        82.954673    83.070522    83.152454    83.218066
# last_sale_price         1.426926     1.172262     3.477592     1.245494
#
# verification_status                                                      \
# contract_type
# rarity_score        83.226013    83.513023    83.522991    83.647753
# last_sale_price         2.870056     3.603472     0.137805     1.506605
#
# verification_status                                                      \
# contract_type
# rarity_score        83.693219    83.827978    83.851996    83.854260
# last_sale_price         0.021999     0.901948     2.804269     4.009449
#
# verification_status                                                      \
# contract_type
# rarity_score        83.869693    84.035020    84.158831    84.196494
# last_sale_price         1.326833     3.200126     0.055492       1.8963
#
# verification_status                                                      \
# contract_type
# rarity_score        84.356048    84.502510    84.579193    84.670761
# last_sale_price         1.177232     2.498555     2.003833     2.003628
#
# verification_status                                                      \
# contract_type
# rarity_score        84.674757    84.719867    84.793711    85.048045
# last_sale_price         2.306669     2.375656     2.940599     3.313896
#
# verification_status                                                      \
# contract_type
# rarity_score        85.077102    85.079046    85.203997    85.208674
# last_sale_price           1.9359     0.690756     0.739311     0.018135
#
# verification_status                                                      \
# contract_type
# rarity_score        85.237230    85.251784    85.264784    85.364150
# last_sale_price         1.694217     3.402582     2.624609     3.103185
#
# verification_status                                                      \
# contract_type
# rarity_score        85.399456    85.454962    85.506315    85.634514
# last_sale_price         2.007238     2.005872     1.904687     3.200379
#
# verification_status                                                      \
# contract_type
# rarity_score        85.714192    85.796578    85.807116    85.944876
# last_sale_price          2.00819     0.989259     2.559344     2.706763
#
# verification_status                                                      \
# contract_type
# rarity_score        85.992412    85.993606    86.051867    86.194388
# last_sale_price         1.964228     2.993722     0.018716     2.009007
#
# verification_status                                                      \
# contract_type
# rarity_score        86.221719    86.395992    86.440198    86.515197
# last_sale_price         2.559733     2.505578     2.000635     3.700456
#
# verification_status                                                      \
# contract_type
# rarity_score        86.559960    86.674425    86.705036    86.774581
# last_sale_price         1.949283     2.311043     2.287311     3.900395
#
# verification_status                                                      \
# contract_type
# rarity_score        86.774772    86.803989    86.812058    86.818600
# last_sale_price         2.352828     1.391402     1.585802     1.707225
#
# verification_status                                                      \
# contract_type
# rarity_score        86.834228    86.890331    86.894339    86.926234
# last_sale_price          2.50769     2.600287     1.307404     2.241572
#
# verification_status                                                      \
# contract_type
# rarity_score        86.933619    87.050399    87.094684    87.154764
# last_sale_price         3.472209     0.056932     0.176058     2.602844
#
# verification_status                                                      \
# contract_type
# rarity_score        87.176194    87.275788    87.466599    87.596858
# last_sale_price         1.903848     0.009664     0.225553     1.102411
#
# verification_status                                                      \
# contract_type
# rarity_score        87.621089    87.656784    87.659053    87.676790
# last_sale_price         1.505916     3.002828     1.905921     0.996504
#
# verification_status                                                      \
# contract_type
# rarity_score        87.682386    87.688925    87.748817    87.791176
# last_sale_price         0.029087     1.997823     3.209985     3.189949
#
# verification_status                                                      \
# contract_type
# rarity_score        87.827570    87.864821    87.897992    87.970865
# last_sale_price         0.618421       1.2366     2.797041     2.122101
#
# verification_status                                                      \
# contract_type
# rarity_score        88.052608    88.105184    88.152101    88.152507
# last_sale_price          1.78665     2.751322      1.98066     3.635967
#
# verification_status                                                      \
# contract_type
# rarity_score        88.162728    88.165240    88.190817    88.222995
# last_sale_price         0.492636     2.985768     0.297676      1.00881
#
# verification_status                                                      \
# contract_type
# rarity_score        88.245658    88.258647    88.316921    88.332697
# last_sale_price         3.003894     2.002533     1.788356     2.193445
#
# verification_status                                                      \
# contract_type
# rarity_score        88.359744    88.370358    88.435511    88.475134
# last_sale_price         2.006058     1.855459     1.885377     1.994469
#
# verification_status                                                      \
# contract_type
# rarity_score        88.492482    88.499979    88.504236    88.547730
# last_sale_price         2.854858     2.000586     2.635431     1.101098
#
# verification_status                                                      \
# contract_type
# rarity_score        88.567310    88.754180    88.799264    88.829213
# last_sale_price         3.201987     0.344933      0.20696     1.650195
#
# verification_status                                                      \
# contract_type
# rarity_score        88.849116    88.895586    88.942706    88.956035
# last_sale_price         1.972124     2.503756     2.655816     1.006518
#
# verification_status                                                      \
# contract_type
# rarity_score        89.001015    89.025264    89.026273    89.128206
# last_sale_price         3.204939      3.16469     2.203794     2.100159
#
# verification_status                                                      \
# contract_type
# rarity_score        89.164052    89.228234    89.264743    89.270341
# last_sale_price         3.407004     0.258979     3.896294     2.873521
#
# verification_status                                                      \
# contract_type
# rarity_score        89.278582    89.280847    89.303342    89.355825
# last_sale_price         1.790666     1.189848     2.736168     2.306191
#
# verification_status                                                      \
# contract_type
# rarity_score        89.384374    89.387607    89.389786    89.432143
# last_sale_price         2.131087     2.400549     2.212531     0.758344
#
# verification_status                                                      \
# contract_type
# rarity_score        89.440385    89.463741    89.507653    89.528152
# last_sale_price         3.115873     2.985399     1.499252     2.258903
#
# verification_status                                                      \
# contract_type
# rarity_score        89.562743    89.574557    89.609696    89.626276
# last_sale_price         2.157388     2.769964     2.007574     2.698025
#
# verification_status                                                      \
# contract_type
# rarity_score        89.643358    89.677946    89.690529    89.694487
# last_sale_price         3.253075     2.499351     2.891394     1.438621
#
# verification_status                                                      \
# contract_type
# rarity_score        89.704276    89.746122    89.764692    89.843801
# last_sale_price         2.506963     2.747863     3.219819     0.894334
#
# verification_status                                                      \
# contract_type
# rarity_score        89.862704    89.905712    89.914103    89.937645
# last_sale_price         2.754378     1.702493     2.308215      0.41009
#
# verification_status                                                      \
# contract_type
# rarity_score        89.940505    89.978707    90.000917    90.019428
# last_sale_price         2.700432      2.00514     1.987593     3.155425
#
# verification_status                                                      \
# contract_type
# rarity_score        90.066227    90.076086    90.079291    90.091209
# last_sale_price         1.906811     2.958696     1.208621     2.084448
#
# verification_status                                                      \
# contract_type
# rarity_score        90.141712    90.157700    90.166233    90.193668
# last_sale_price         3.003211     0.915734     1.499318     3.339151
#
# verification_status                                                      \
# contract_type
# rarity_score        90.204702    90.231528    90.303367    90.350197
# last_sale_price         0.341322     0.759443     4.505244      1.99995
#
# verification_status                                                      \
# contract_type
# rarity_score        90.352158    90.354171    90.359859    90.368301
# last_sale_price         0.225391     0.204215     2.805511     3.106764
#
# verification_status                                                      \
# contract_type
# rarity_score        90.400232    90.416988    90.431903    90.475912
# last_sale_price         1.005524     2.993832     0.300157     1.801126
#
# verification_status                                                      \
# contract_type
# rarity_score        90.505528    90.519522    90.528162    90.536613
# last_sale_price         1.807841     0.165794     3.504876     1.754302
#
# verification_status                                                      \
# contract_type
# rarity_score        90.594917    90.632745    90.645192    90.648525
# last_sale_price         2.883163     1.651352     2.788799      2.33999
#
# verification_status                                                      \
# contract_type
# rarity_score        90.653015    90.696747    90.754852    90.758413
# last_sale_price         0.234521     0.225746     1.905837     0.999236
#
# verification_status                                                      \
# contract_type
# rarity_score        90.759099    90.787840    90.803544    90.936768
# last_sale_price         0.942795     2.009314     1.980716     0.201171
#
# verification_status                                                      \
# contract_type
# rarity_score        90.938772    90.950132    91.001411    91.015883
# last_sale_price         1.008019     2.506422     0.006305      1.58727
#
# verification_status                                                      \
# contract_type
# rarity_score        91.025998    91.032567    91.075636    91.077101
# last_sale_price         0.347947     2.504272     3.199086      2.79812
#
# verification_status                                                      \
# contract_type
# rarity_score        91.079639    91.114694    91.141047    91.146614
# last_sale_price         2.302703     1.307664     1.098587     2.522732
#
# verification_status                                                      \
# contract_type
# rarity_score        91.149989    91.156129    91.260797    91.295471
# last_sale_price         2.953961     0.905633     2.004521     3.992922
#
# verification_status                                                      \
# contract_type
# rarity_score        91.314747    91.427276    91.442209    91.471635
# last_sale_price         1.797894     1.998362     1.242881     1.878038
#
# verification_status                                                      \
# contract_type
# rarity_score        91.503888    91.514124    91.566071    91.571540
# last_sale_price         2.201715     1.255348     1.904182     3.508045
#
# verification_status                                                      \
# contract_type
# rarity_score        91.585531    91.588960    91.640848    91.659242
# last_sale_price         1.691044     3.558077     2.181998     1.324722
#
# verification_status                                                      \
# contract_type
# rarity_score        91.665329    91.670793    91.683133    91.694023
# last_sale_price         1.207061      3.20282     0.398852     2.841686
#
# verification_status                                                      \
# contract_type
# rarity_score        91.742973    91.797884    91.822138    91.831707
# last_sale_price         0.769989     1.254157     3.009395       0.8551
#
# verification_status                                                      \
# contract_type
# rarity_score        91.833566    91.856778    91.897925    91.923293
# last_sale_price         2.897915     2.203501     4.002247     1.558192
#
# verification_status                                                      \
# contract_type
# rarity_score        91.943840    91.955886    91.973838    92.000760
# last_sale_price         2.402834     0.756868     1.409353     0.043806
#
# verification_status                                                      \
# contract_type
# rarity_score        92.013898    92.021488    92.037557    92.047544
# last_sale_price         2.228722     2.803622     0.203025     3.284161
#
# verification_status                                                      \
# contract_type
# rarity_score        92.055573    92.090128    92.098681    92.157829
# last_sale_price         1.574748     3.209762     0.017859     2.451405
#
# verification_status                                                      \
# contract_type
# rarity_score        92.170500    92.181638    92.210730    92.213519
# last_sale_price         3.552402     0.500095     4.505302     1.241203
#
# verification_status                                                      \
# contract_type
# rarity_score        92.222032    92.239534    92.275165    92.295176
# last_sale_price         1.699106     2.307659     3.009593     1.697449
#
# verification_status                                                      \
# contract_type
# rarity_score        92.305715    92.308153    92.324455    92.356207
# last_sale_price         1.903463      2.19987     4.008007     2.285197
#
# verification_status                                                      \
# contract_type
# rarity_score        92.358780    92.431435    92.470092    92.494054
# last_sale_price         1.204033      3.07716      1.85726     1.062717
#
# verification_status                                                      \
# contract_type
# rarity_score        92.511128    92.512847    92.527568    92.528960
# last_sale_price         2.501149     2.854079     0.337038     2.207278
#
# verification_status                                                      \
# contract_type
# rarity_score        92.560604    92.587142    92.591154    92.604322
# last_sale_price            2.156      1.99102     1.697628      2.84563
#
# verification_status                                                      \
# contract_type
# rarity_score        92.620131    92.624563    92.628458    92.650412
# last_sale_price          1.94037     3.006201     2.192559     2.502392
#
# verification_status                                                      \
# contract_type
# rarity_score        92.655493    92.658457    92.658935    92.660581
# last_sale_price         1.383873     1.200894     1.871635     3.003502
#
# verification_status                                                      \
# contract_type
# rarity_score        92.664271    92.681628    92.728089    92.751430
# last_sale_price         2.933311     3.343732     1.789883     0.941414
#
# verification_status                                                      \
# contract_type
# rarity_score        92.761286    92.793204    92.801762    92.845855
# last_sale_price         2.801453     0.146339     1.905808     3.953586
#
# verification_status                                                      \
# contract_type
# rarity_score        92.877036    92.896850    92.905365    92.932194
# last_sale_price         1.006369     0.569001      3.79926     1.809573
#
# verification_status                                                      \
# contract_type
# rarity_score        92.935253    92.973923    92.994249    93.020949
# last_sale_price         3.272277     0.021874     0.969995      2.65553
#
# verification_status                                                      \
# contract_type
# rarity_score        93.026547    93.040227    93.048320    93.050325
# last_sale_price         3.103163     0.788374     2.382631     2.793265
#
# verification_status                                                      \
# contract_type
# rarity_score        93.055723    93.094766    93.134118    93.143609
# last_sale_price         1.870501     3.803894     1.990772     0.453459
#
# verification_status                                                      \
# contract_type
# rarity_score        93.241502    93.288767    93.297963    93.299644
# last_sale_price         0.407682     1.704442     2.940208     2.966619
#
# verification_status                                                      \
# contract_type
# rarity_score        93.322003    93.356113    93.379925    93.502453
# last_sale_price         2.008481      0.95215     1.104251     1.553263
#
# verification_status                                                      \
# contract_type
# rarity_score        93.518458    93.522912    93.524098    93.525995
# last_sale_price         0.909216     2.704418     0.818953     1.991361
#
# verification_status                                                      \
# contract_type
# rarity_score        93.569136    93.606754    93.611095    93.668180
# last_sale_price         3.690311     1.786495     1.854301     2.258646
#
# verification_status                                                      \
# contract_type
# rarity_score        93.696465    93.705869    93.726670    93.771082
# last_sale_price         1.871315     3.492258     0.948187     1.667991
#
# verification_status                                                      \
# contract_type
# rarity_score        93.780904    93.831480    93.856993    93.861329
# last_sale_price         1.503335     0.705707     1.490675     2.505792
#
# verification_status                                                      \
# contract_type
# rarity_score        93.871088    93.872612    93.916002    93.968289
# last_sale_price         2.104381     1.351478     1.299337     2.639606
#
# verification_status                                                      \
# contract_type
# rarity_score        93.974604    93.977113    93.978974    93.989390
# last_sale_price         2.004112     3.996011     0.986166     1.399804
#
# verification_status                                                      \
# contract_type
# rarity_score        93.996220    94.010671    94.012097    94.018240
# last_sale_price         2.225288     1.600713     1.201325     2.300223
#
# verification_status                                                      \
# contract_type
# rarity_score        94.063365    94.070891    94.071301    94.075151
# last_sale_price         0.317795     1.927807     9.003325     0.958961
#
# verification_status                                                      \
# contract_type
# rarity_score        94.075417    94.087482    94.098668    94.109845
# last_sale_price          2.57506     3.000116     0.007481     0.862095
#
# verification_status                                                      \
# contract_type
# rarity_score        94.133567    94.139521    94.156997    94.185418
# last_sale_price         3.754636     2.993194     3.196308     2.263635
#
# verification_status                                                      \
# contract_type
# rarity_score        94.199646    94.268058    94.281587    94.293184
# last_sale_price         2.775744     2.998095      1.93094     3.507618
#
# verification_status                                                      \
# contract_type
# rarity_score        94.298611    94.308889    94.342833    94.351594
# last_sale_price         2.009327     2.508146      2.20033     3.009671
#
# verification_status                                                      \
# contract_type
# rarity_score        94.371787    94.372537    94.391615    94.423632
# last_sale_price         3.898987      3.00634     3.009644     3.255811
#
# verification_status                                                      \
# contract_type
# rarity_score        94.434016    94.462053    94.501585    94.503107
# last_sale_price         2.956887     3.904856     2.701435     2.328636
#
# verification_status                                                      \
# contract_type
# rarity_score        94.507715    94.527212    94.535200    94.565153
# last_sale_price         1.803098     6.900152     0.496274     2.305455
#
# verification_status                                                      \
# contract_type
# rarity_score        94.571155    94.591048    94.596671    94.606371
# last_sale_price          1.32153     7.002326     2.059201      2.59346
#
# verification_status                                                      \
# contract_type
# rarity_score        94.610537    94.641599    94.645792    94.661836
# last_sale_price         0.341763     2.887199     2.344267     2.803436
#
# verification_status                                                      \
# contract_type
# rarity_score        94.675995    94.684914    94.691253    94.708901
# last_sale_price         1.892239     1.238086     1.156589     2.795613
#
# verification_status                                                      \
# contract_type
# rarity_score        94.718879    94.757938    94.760500    94.762551
# last_sale_price         2.076981     3.733513     2.485656     0.002466
#
# verification_status                                                      \
# contract_type
# rarity_score        94.795496    94.846883    94.855862    94.870680
# last_sale_price         3.856563     2.268343     2.375896     2.983853
#
# verification_status                                                      \
# contract_type
# rarity_score        94.893107    94.900379    94.950772    94.983292
# last_sale_price         1.107701     2.803029     3.098143     2.997219
#
# verification_status                                                      \
# contract_type
# rarity_score        94.988683    95.006629    95.012161    95.072512
# last_sale_price         2.007012     3.849419     0.851604     0.017434
#
# verification_status                                                      \
# contract_type
# rarity_score        95.080971    95.146058    95.164351    95.170574
# last_sale_price         3.008873     1.095468      1.57969     2.105309
#
# verification_status                                                      \
# contract_type
# rarity_score        95.185506    95.199083    95.213108    95.256733
# last_sale_price         0.021604     1.400196     0.197791     2.804945
#
# verification_status                                                      \
# contract_type
# rarity_score        95.288764    95.290415    95.298565    95.321151
# last_sale_price         0.701446     2.100002      2.40031      3.10587
#
# verification_status                                                      \
# contract_type
# rarity_score        95.324532    95.329374    95.350718    95.350800
# last_sale_price         1.270352     2.885058     3.896482     1.689084
#
# verification_status                                                      \
# contract_type
# rarity_score        95.374324    95.375881    95.417178    95.425200
# last_sale_price         3.105686     1.394919      2.00546     1.257638
#
# verification_status                                                      \
# contract_type
# rarity_score        95.471301    95.481109    95.511688    95.522723
# last_sale_price          0.45548     0.580616      2.60506     0.928846
#
# verification_status                                                      \
# contract_type
# rarity_score        95.532060    95.543237    95.545883    95.566035
# last_sale_price         2.108143     7.001361     1.453157     2.995208
#
# verification_status                                                      \
# contract_type
# rarity_score        95.617714    95.620950    95.624030    95.633593
# last_sale_price          3.30859     2.495642     0.854816      0.44344
#
# verification_status                                                      \
# contract_type
# rarity_score        95.650057    95.680154    95.680726    95.720250
# last_sale_price         3.734152     0.019899      2.70493     1.955223
#
# verification_status                                                      \
# contract_type
# rarity_score        95.812468    95.846884    95.876802    95.889661
# last_sale_price         1.143878     1.202859     2.555685     2.259542
#
# verification_status                                                      \
# contract_type
# rarity_score        95.957326    95.962349    95.962694    95.964189
# last_sale_price         1.952895       0.0648     0.218153     3.105531
#
# verification_status                                                      \
# contract_type
# rarity_score        95.964552    95.967126    95.967223    95.969232
# last_sale_price         0.389171     0.929681     0.051826     4.406207
#
# verification_status                                                      \
# contract_type
# rarity_score        95.977691    95.996778    96.011536    96.044035
# last_sale_price         2.885398      2.40241     1.102574     2.900711
#
# verification_status                                                      \
# contract_type
# rarity_score        96.045834    96.059445    96.073495    96.085062
# last_sale_price         1.906344     1.106223     3.833343     2.755499
#
# verification_status                                                      \
# contract_type
# rarity_score        96.107221    96.119309    96.131162    96.145849
# last_sale_price         1.246115     2.159209     3.750136     1.706854
#
# verification_status                                                      \
# contract_type
# rarity_score        96.159715    96.160620    96.187998    96.189178
# last_sale_price         1.201646     3.089222     2.659162     2.307665
#
# verification_status                                                      \
# contract_type
# rarity_score        96.196177    96.212603    96.218670    96.240720
# last_sale_price         4.002685     2.609972      2.50822     0.142772
#
# verification_status                                                      \
# contract_type
# rarity_score        96.245810    96.262583    96.288725    96.290141
# last_sale_price         2.905365     1.733862     2.476794     2.502826
#
# verification_status                                                      \
# contract_type
# rarity_score        96.333277    96.349250    96.354587    96.377225
# last_sale_price         0.950755     2.103242     0.821444     2.253895
#
# verification_status                                                      \
# contract_type
# rarity_score        96.382710    96.412064    96.428390    96.455680
# last_sale_price         0.702888     1.385796     0.189791     1.949309
#
# verification_status                                                      \
# contract_type
# rarity_score        96.463618    96.465997    96.470157    96.488755
# last_sale_price         1.401657     2.920627     3.502744     3.081266
#
# verification_status                                                      \
# contract_type
# rarity_score        96.491825    96.523864    96.541167    96.545971
# last_sale_price         2.584316     0.955547     2.007689     0.256057
#
# verification_status                                                      \
# contract_type
# rarity_score        96.546005    96.579567    96.584363    96.591320
# last_sale_price         1.129535     2.304759     0.437704     1.105781
#
# verification_status                                                      \
# contract_type
# rarity_score        96.594440    96.597413    96.652510    96.669432
# last_sale_price         1.551101     2.107505     0.412794      2.63845
#
# verification_status                                                      \
# contract_type
# rarity_score        96.725797    96.752665    96.781221    96.790631
# last_sale_price         1.205136     2.295148     3.700285     1.544764
#
# verification_status                                                      \
# contract_type
# rarity_score        96.804921    96.824327    96.837854    96.840835
# last_sale_price         3.689633     2.500337     4.157337     2.193215
#
# verification_status                                                      \
# contract_type
# rarity_score        96.858940    96.884467    96.902558    96.933313
# last_sale_price          2.90686     1.401263     3.308322     3.503598
#
# verification_status                                                      \
# contract_type
# rarity_score        96.933533    96.979238    96.992986    96.993603
# last_sale_price         2.142832     0.117904     2.601068     0.505472
#
# verification_status                                                      \
# contract_type
# rarity_score        96.999272    97.025351    97.029081    97.049792
# last_sale_price         2.907311     4.001001     2.257313     1.639108
#
# verification_status                                                      \
# contract_type
# rarity_score        97.051249    97.064800    97.076029    97.077216
# last_sale_price          2.88409     1.373121     2.453582     1.200357
#
# verification_status                                                      \
# contract_type
# rarity_score        97.091609    97.110043    97.134324    97.135425
# last_sale_price         1.361492     3.101083     1.409524     1.398115
#
# verification_status                                                      \
# contract_type
# rarity_score        97.143349    97.143488    97.146317    97.185747
# last_sale_price         2.158264     0.008602      2.09634     1.248296
#
# verification_status                                                      \
# contract_type
# rarity_score        97.189422    97.191657    97.204036    97.211009
# last_sale_price         2.206524     0.054423     1.956623     3.005378
#
# verification_status                                                      \
# contract_type
# rarity_score        97.219825    97.223499    97.250246    97.264796
# last_sale_price          1.89789     3.558295     3.004013     2.300015
#
# verification_status                                                      \
# contract_type
# rarity_score        97.264989    97.269913    97.272605    97.295184
# last_sale_price         3.509225     2.806146     1.495418     4.258135
#
# verification_status                                                      \
# contract_type
# rarity_score        97.358342    97.361252    97.362844    97.376748
# last_sale_price         1.850009     1.703298     1.187557     2.693973
#
# verification_status                                                      \
# contract_type
# rarity_score        97.379566    97.390145    97.399326    97.405289
# last_sale_price          3.10437     3.507621     3.994957     2.709963
#
# verification_status                                                      \
# contract_type
# rarity_score        97.421207    97.444230    97.457001    97.468317
# last_sale_price         0.453836     1.758903      3.60569     0.002621
#
# verification_status                                                      \
# contract_type
# rarity_score        97.526881    97.529655    97.542800    97.551285
# last_sale_price         2.993286     1.523827     2.309647     0.959429
#
# verification_status                                                      \
# contract_type
# rarity_score        97.560432    97.574850    97.578751    97.586591
# last_sale_price         5.509522     0.979624     3.006846     2.658639
#
# verification_status                                                      \
# contract_type
# rarity_score        97.590603    97.607946    97.610099    97.620709
# last_sale_price         3.001073     2.002814     1.507369     4.285523
#
# verification_status                                                      \
# contract_type
# rarity_score        97.637492    97.648503    97.657386    97.671017
# last_sale_price         0.207107     2.609831     2.004118     1.293305
#
# verification_status                                                      \
# contract_type
# rarity_score        97.679437    97.692421    97.697243    97.698759
# last_sale_price          2.60144     4.199238     3.892741     0.243674
#
# verification_status                                                      \
# contract_type
# rarity_score        97.724046    97.744160    97.763579    97.777128
# last_sale_price         1.881303      6.49528     0.972469     1.733135
#
# verification_status                                                      \
# contract_type
# rarity_score        97.783577    97.793944    97.801095    97.842123
# last_sale_price         2.380163      1.20691     2.343217     0.818783
#
# verification_status                                                      \
# contract_type
# rarity_score        97.857678    97.863198    97.864013    97.879840
# last_sale_price         3.550403     3.202458     3.272271     0.401116
#
# verification_status                                                      \
# contract_type
# rarity_score        97.881081    97.884502    97.899167    97.906394
# last_sale_price         3.156968     3.289895     1.707994     0.482904
#
# verification_status                                                      \
# contract_type
# rarity_score        97.921310    97.922903    97.955360    97.987146
# last_sale_price         2.228335     2.253309     2.160315     2.616979
#
# verification_status                                                      \
# contract_type
# rarity_score        98.028830    98.058321    98.059703    98.079985
# last_sale_price         2.904953      1.93985     0.959112     4.202037
#
# verification_status                                                      \
# contract_type
# rarity_score        98.089817    98.090156    98.098017    98.103929
# last_sale_price         1.245391      2.30433     2.821895     0.653285
#
# verification_status                                                      \
# contract_type
# rarity_score        98.125464    98.144727    98.148165    98.168587
# last_sale_price         0.937591     8.758464     1.225943     2.302054
#
# verification_status                                                      \
# contract_type
# rarity_score        98.170034    98.194306    98.213471    98.233596
# last_sale_price         2.645683     1.942078     0.004304     4.008984
#
# verification_status                                                      \
# contract_type
# rarity_score        98.233795    98.240161    98.251495    98.259757
# last_sale_price         2.909204     0.003726     3.224369     0.003534
#
# verification_status                                                      \
# ...
# rarity_score        2568.458804  2568.843751  2570.644829  2571.375404
# last_sale_price         0.021857     0.075804     0.202651     0.049706
#
# verification_status                                                      \
# contract_type
# rarity_score        2571.633700  2571.974091  2571.995795  2573.835400
# last_sale_price         0.008481      0.00681     0.005087     0.004297
#
# verification_status                                                      \
# contract_type
# rarity_score        2576.979953  2578.046779  2578.086640  2578.413352
# last_sale_price         0.040222      0.00123     0.000421     0.022131
#
# verification_status                                                      \
# contract_type
# rarity_score        2580.852066  2581.120404  2581.216568  2583.850779
# last_sale_price         0.004095     0.540789     0.009991     0.152974
#
# verification_status                                                      \
# contract_type
# rarity_score        2585.373942  2588.008707  2592.470557  2595.622183
# last_sale_price         0.071585     0.005372      0.00373     0.009243
#
# verification_status                                                      \
# contract_type
# rarity_score        2596.962708  2597.055620  2598.812486  2599.049489
# last_sale_price         0.005509     0.006175     0.002668     0.011939
#
# verification_status                                                      \
# contract_type
# rarity_score        2600.408828  2601.211623  2607.096489  2611.600244
# last_sale_price         0.096669     0.156897     0.391594     0.155017
#
# verification_status                                                      \
# contract_type
# rarity_score        2613.261649  2616.796996  2617.127642  2618.143512
# last_sale_price         0.007657     0.025993      0.00226     0.257539
#
# verification_status                                                      \
# contract_type
# rarity_score        2619.917202  2622.731923  2623.269972  2623.630015
# last_sale_price          0.00006     0.109873     0.085017     0.053975
#
# verification_status                                                      \
# contract_type
# rarity_score        2623.824099  2623.907658  2624.610907  2624.693774
# last_sale_price           0.0647     0.220392     0.048753     0.009795
#
# verification_status                                                      \
# contract_type
# rarity_score        2625.232524  2626.417046  2626.611768  2627.611884
# last_sale_price         0.058511     0.087426     0.152513     0.074742
#
# verification_status                                                      \
# contract_type
# rarity_score        2628.389302  2630.644004  2631.859830  2637.068942
# last_sale_price          0.00052     0.138537      0.00355      0.07129
#
# verification_status                                                      \
# contract_type
# rarity_score        2639.230751  2640.190950  2641.015902  2641.409518
# last_sale_price         0.002523     0.084341     0.003906     0.007863
#
# verification_status                                                      \
# contract_type
# rarity_score        2644.140926  2648.227273  2650.933204  2651.702214
# last_sale_price         0.003364     0.007222     0.120383     0.004949
#
# verification_status                                                      \
# contract_type
# rarity_score        2658.250230  2662.249637  2665.726329  2667.003436
# last_sale_price         0.105669     0.006072     0.250289     0.019743
#
# verification_status                                                      \
# contract_type
# rarity_score        2667.298727  2669.258224  2672.952742  2677.537950
# last_sale_price         0.006625     0.128962     0.203712     0.135441
#
# verification_status                                                      \
# contract_type
# rarity_score        2678.036079  2680.436268  2681.234175  2683.486238
# last_sale_price         0.002523     0.008981     0.005548     0.004259
#
# verification_status                                                      \
# contract_type
# rarity_score        2685.238636  2687.298080  2688.029032  2688.137679
# last_sale_price          0.00315     0.006192     0.007977     0.142926
#
# verification_status                                                      \
# contract_type
# rarity_score        2688.997944  2689.128752  2690.064204  2691.020143
# last_sale_price         0.028545     0.006814     0.016194     0.005491
#
# verification_status                                                      \
# contract_type
# rarity_score        2697.012105  2700.243451  2700.401249  2710.015513
# last_sale_price          0.00463       0.0218     0.108839     0.015454
#
# verification_status                                                      \
# contract_type
# rarity_score        2710.692646  2712.748476  2716.793754  2717.173176
# last_sale_price         0.142556     0.007064     0.001747       0.0125
#
# verification_status                                                      \
# contract_type
# rarity_score        2717.709303  2722.120679  2730.874297  2733.340428
# last_sale_price          0.00132     0.035042     0.005106     0.209698
#
# verification_status                                                      \
# contract_type
# rarity_score        2738.643858  2740.313131  2742.321780  2746.991677
# last_sale_price          0.06707     0.169968     0.111403     0.009116
#
# verification_status                                                      \
# contract_type
# rarity_score        2747.570057  2748.388848  2751.943602  2759.772634
# last_sale_price         0.004388     0.041341      0.01684     0.000652
#
# verification_status                                                      \
# contract_type
# rarity_score        2760.939890  2762.118146  2770.349661  2774.499818
# last_sale_price          0.00098     0.007725     0.018373     0.004922
#
# verification_status                                                      \
# contract_type
# rarity_score        2780.518730  2784.973090  2786.098977  2790.913790
# last_sale_price         0.176898     0.100728     0.004236     0.030918
#
# verification_status                                                      \
# contract_type
# rarity_score        2793.307785  2802.095517  2804.871882  2805.636731
# last_sale_price         0.099263     0.041947     0.039225     0.121149
#
# verification_status                                                      \
# contract_type
# rarity_score        2812.696513  2815.897428  2821.694932  2823.794494
# last_sale_price         0.002972     0.118446     0.000068     0.005528
#
# verification_status                                                      \
# contract_type
# rarity_score        2824.329315  2826.456328  2827.389596  2834.368420
# last_sale_price         0.007327     0.005681     0.005701     0.014203
#
# verification_status                                                      \
# contract_type
# rarity_score        2837.376233  2843.022163  2849.068187  2862.338231
# last_sale_price         0.005746     0.007099      0.00118     0.041601
#
# verification_status                                                      \
# contract_type
# rarity_score        2912.528741  2915.915848  2931.064455  2943.867134
# last_sale_price         0.152057     0.008297     0.150594     0.018149
#
# verification_status                                                      \
# contract_type
# rarity_score        2944.439907  2982.996792  2991.472780  2992.138562
# last_sale_price         0.284215     0.002448     0.034995     0.506959
#
# verification_status                                                      \
# contract_type
# rarity_score        2995.622703  3014.068535  3019.531229  3019.720265
# last_sale_price         0.007353     0.018389     0.077879     0.006246
#
# verification_status                                                      \
# contract_type
# rarity_score        3038.682228  3041.370366  3059.429747  3062.987784
# last_sale_price         0.000107     0.025762     0.479399     0.009321
#
# verification_status                                                      \
# contract_type
# rarity_score        3063.935705  3071.612412  3085.097653  3121.325312
# last_sale_price          0.00135     0.096158     0.182832     0.000328
#
# verification_status                                                      \
# contract_type
# rarity_score        3127.685121  3134.200900  3146.776461  3149.114926
# last_sale_price         0.251168     0.008059     0.175393     0.001158
#
# verification_status                                                      \
# contract_type
# rarity_score        3174.975290  3193.577904  3195.854075  3207.438386
# last_sale_price         0.009054     0.146175     0.000996     0.178494
#
# verification_status                                                      \
# contract_type
# rarity_score        3215.169540  3228.549398  3257.146164  3266.687208
# last_sale_price          0.11785     0.003855     0.019901     0.003401
#
# verification_status                                                      \
# contract_type
# rarity_score        3284.951662  3392.856754  3502.335586  3518.529727
# last_sale_price         0.042227     0.025304     0.202881     0.166554
#
# verification_status                                                      \
# contract_type
# rarity_score        3557.136449  3578.408634  3610.993944  3624.280758
# last_sale_price         0.003288     0.137704     0.102037     0.078079
#
# verification_status                                                      \
# contract_type
# rarity_score        3626.745691  3632.385380  3646.293517  3667.534025
# last_sale_price         0.004174      0.00852     0.056209     0.027596
#
# verification_status                                                      \
# contract_type
# rarity_score        3772.770993  3773.042729  3860.754137  4121.765885
# last_sale_price         0.184758     0.000682     0.005859     0.003616
#
# verification_status                                                      \
# contract_type
# rarity_score        4401.326625  4428.657155  4540.862434  4640.986503
# last_sale_price         0.005942     0.008957     0.001806     0.407884
#
# verification_status                                                      \
# contract_type
# rarity_score        4704.792916  5136.198511  10302.493600 10349.788250
# last_sale_price         0.491157     0.030945     0.009478     0.008539
#
# verification_status                                                      \
# contract_type
# rarity_score        10372.825640 10449.059730 10458.102780 10464.985640
# last_sale_price          0.25741     0.001427     0.006423     1.101821
#
# verification_status                                                      \
# contract_type
# rarity_score        10466.643640 10486.287640 10493.593600 10518.498120
# last_sale_price          0.00757      1.70049     0.039707     1.007077
#
# verification_status                                                      \
# contract_type
# rarity_score        10519.600680 10556.864780 10567.494800 10567.696670
# last_sale_price         0.254271     0.081524     0.454315     0.009639
#
# verification_status                                                      \
# contract_type
# rarity_score        10571.202790 10590.258570 10610.390240 10632.496730
# last_sale_price         0.666075     0.006679      0.00472     0.001779
#
# verification_status                                                      \
# contract_type
# rarity_score        10633.757190 10638.118850 10645.458500 10647.183710
# last_sale_price         0.005366     0.007975     0.001857     0.000242
#
# verification_status                                                      \
# contract_type
# rarity_score        10686.236470 10694.499050 10703.459610 10708.247570
# last_sale_price         0.538908     0.805104      0.00758     0.155599
#
# verification_status                                                      \
# contract_type
# rarity_score        10732.729890 10754.953880 10785.488320 10825.655880
# last_sale_price         0.659897     0.032665     0.000813     1.991656
#
# verification_status                                                      \
# contract_type
# rarity_score        10927.419690 10931.575570 10962.115610 11094.483280
# last_sale_price         0.006438     2.504006     0.006503     0.004571
#
# verification_status                                                      \
# contract_type
# rarity_score        11590.586710 12462.147110 28896.287040 35587.552000
# last_sale_price         0.007128     0.501272   230.007048   400.001379
#
# verification_status
# contract_type
# rarity_score        37774.000000
# last_sale_price       169.007275

# %%
nft.pivot_table(index = 'verification_status' , columns=['contract_type' , 'rarity_score' , 'last_sale_price'])
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_17048\2345521086.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   nft.pivot_table(index = 'verification_status' , columns=['contract_type' , 'rarity_score' , 'last_sale_price'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nft.pivot_table(index = 'verification_status' , columns=['contract_type' , 'rarity_score' , 'last_sale_price'])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:151, in DisplayHook.compute_format_data(self, result)
#     121 def compute_format_data(self, result):
#     122     """Compute format data of the object to be displayed.
#     123
#     124     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     149
#     150     """
# --> 151     return self.shell.display_formatter.format(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:1063, in DataFrame.__repr__(self)
#    1060     return buf.getvalue()
#    1062 repr_params = fmt.get_dataframe_repr_params()
# -> 1063 return self.to_string(**repr_params)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:1244, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1225 with option_context("display.max_colwidth", max_colwidth):
#    1226     formatter = fmt.DataFrameFormatter(
#    1227         self,
#    1228         columns=columns,
#    (...)
#    1242         decimal=decimal,
#    1243     )
# -> 1244     return fmt.DataFrameRenderer(formatter).to_string(
#    1245         buf=buf,
#    1246         encoding=encoding,
#    1247         line_width=line_width,
#    1248     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:872, in DataFrameFormatter._get_strcols_without_index(self)
#     870     str_columns = [[label] for label in self.header]
#     871 else:
# --> 872     str_columns = self._get_formatted_column_labels(self.tr_frame)
#     874 if self.show_row_idx_names:
#     875     for x in str_columns:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:943, in DataFrameFormatter._get_formatted_column_labels(self, frame)
#     939         return " " + y
#     940     return y
#     942 str_columns = list(
# --> 943     zip(*([space_format(x, y) for y in x] for x in fmt_columns))
#     944 )
#     945 if self.sparsify and len(str_columns):
#     946     str_columns = sparsify_labels(str_columns)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:943, in <genexpr>(.0)
#     939         return " " + y
#     940     return y
#     942 str_columns = list(
# --> 943     zip(*([space_format(x, y) for y in x] for x in fmt_columns))
#     944 )
#     945 if self.sparsify and len(str_columns):
#     946     str_columns = sparsify_labels(str_columns)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:943, in <listcomp>(.0)
#     939         return " " + y
#     940     return y
#     942 str_columns = list(
# --> 943     zip(*([space_format(x, y) for y in x] for x in fmt_columns))
#     944 )
#     945 if self.sparsify and len(str_columns):
#     946     str_columns = sparsify_labels(str_columns)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:934, in DataFrameFormatter._get_formatted_column_labels.<locals>.space_format(x, y)
#     933 def space_format(x, y):
# --> 934     if (
#     935         y not in self.formatters
#     936         and need_leadsp[x]
#     937         and not restrict_formatting
#     938     ):
#     939         return " " + y
#     940     return y
#
# KeyboardInterrupt:

# %%
nft.pivot_table(index = 'verification_status' , columns=['contract_type' , 'rarity_score' , 'last_sale_price'])
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_17048\2345521086.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   nft.pivot_table(index = 'verification_status' , columns=['contract_type' , 'rarity_score' , 'last_sale_price'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 nft.pivot_table(index = 'verification_status' , columns=['contract_type' , 'rarity_score' , 'last_sale_price'])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:151, in DisplayHook.compute_format_data(self, result)
#     121 def compute_format_data(self, result):
#     122     """Compute format data of the object to be displayed.
#     123
#     124     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     149
#     150     """
# --> 151     return self.shell.display_formatter.format(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:1063, in DataFrame.__repr__(self)
#    1060     return buf.getvalue()
#    1062 repr_params = fmt.get_dataframe_repr_params()
# -> 1063 return self.to_string(**repr_params)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:1244, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1225 with option_context("display.max_colwidth", max_colwidth):
#    1226     formatter = fmt.DataFrameFormatter(
#    1227         self,
#    1228         columns=columns,
#    (...)
#    1242         decimal=decimal,
#    1243     )
# -> 1244     return fmt.DataFrameRenderer(formatter).to_string(
#    1245         buf=buf,
#    1246         encoding=encoding,
#    1247         line_width=line_width,
#    1248     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:1310, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1307     space = 12
#    1309 if float_format is None:
# -> 1310     float_format = get_option("display.float_format")
#    1312 if digits is None:
#    1313     digits = get_option("display.precision")
#
# KeyboardInterrupt:

# %% [markdown]
# ### `Question-2:`
#
# You are given a dataset about the cars' price and miles driven of different cars throughout the different years. The link of the dataset: https://tinyurl.com/2r24n45l. Your tasks are
# - make a pivot table of the brands (the required brands are given below) from the "Year" 2018 to the year 2022 in which the "Price" is shown as average values and "Miles" are in median values. In this pivote table, every row represents a particular brand and each column represents either average "Price" of a partucular year or median values of "Miles" of a particular year.
# - At the end plot a kde chart for the "Price" and "Miles" by using your pivot table.
#
# There are some challenges to solve this task:
# - There is no column that is represented to the brand name of the car. You have to find out on your own.
# - Some values of "Years" column are misleading. You have to reset this column too that every value should tell a valid meaning.

# %%
# code here

# %% [markdown]
# ### `Question-3:`
#
# You are given a dataset of **Daily Power Generation in India** of regional wise of all Power Stations. Link of the dataset: https://tinyurl.com/2nq6kugt
#
# Task
# - In this dataset, there are many columns. Two of them are `Actual(MU)` and `Excess(+) / Shortfall (-)`. `Actual(MU)` represents the actual power generation. `Excess(+) / Shortfall (-)` tells is that generated power is excess or shortfall for that particular day of a power station. You have to find out what should be the actual power generation required for that day by the power stations that there would not be any excess or shorfall power. For the result, make a new column.
# - Find out the month of the day and store it as a new column.
# - Find out top 10 frequently appeared power stations in this dataframe.
# - Next create a pivot table of which every row represents a power station and every column represents a month in a order. Like January, February, March...
# - It is hard to get inside if you look through the only pivot table. So plot the pivot table.

# %%
# code here

# %% [markdown]
# ###`Q-4` You are given a file `question-answer.csv`. Your task is to make a dataframe from it with two columns - `question` and `answers`.
#
# * Questions in the file start from `Q<number>`; E.g.  `Q1` denotes question no. `1`
# * Answers starts from `Ans<number>`; Eg. `Ans1` denotes answer of question no `1`
# * MAke sure you look at columns name carefully
#
# CSV File - "https://drive.google.com/file/d/10rmV3XrVtzpDTtYZF3UtCdcU0ajBJjGY/view?usp=share_link"

# %%
# code here

# %% [markdown]
# ###`Q-5`: Print Question and answer of those questions which does not contains any question mark (`?`).

# %%
# code here

# %% [markdown]
# ###`Q 6-10` LOG and EMPLOYEE
# 6. Show `activity` details month wise. Show count for each `activity`
# 7. Find employee who did most `activity` in January month.
# 8. Employee who have worked most no of times on Weekends.
# 9. Which activity is logged most on buisness days.
# 10. Week Days wise activity table.
# ```
# log_file = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT-OMrmmNdOTM-B5f5F1EpCutMVG230UZiLvqlsg0NIKUKR3yrqiI2r1pEX-LvSEk-3WwySPYtvbBC-/pub?gid=1937029224&single=true&output=csv")
# employee = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ5AuFqRjSZVBKm5zyDxquX6utubq1DJKkYDI70vjeidAnyAu70KMSYpMYzeVSNVTeUIJBpfF6jU5E6/pub?gid=798824749&single=true&output=csv")
#
# ```
#
# Note(for common field):- Employee file has `EMPLOYEE_ID` and LOG file has `emp_id`

# %%
# code here

# %% [markdown]
# ### `Q-11`:
#
# 1. There are missing value in first name of employee. Fill it using email and last name field.
#
# > E.g- `email` -> JMURMAN and `last_name` -> 'Urman' -> so make it's first name as 'JM', Sort of (Email- lastname).
#
# > Email is constructed from initials of first name concate with lastname. Your Task is to fill first name initials in missing data.
#
# 2. You can see email field don't have any domain name. Change this to full email addreess with domain as 'campusx.com'.
# E.g- Email field -> `JMURMAN`  result -> `JMURMAN@CAMPUSX.COM`
#
# 3. Show Full Name of all the employees whose name starts with 'A' and has done any of these activity ['Incpection', 'Cleaning', 'Checking]

# %%
# code here
